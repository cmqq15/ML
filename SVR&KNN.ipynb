# %% [markdown]
# # Support Vector Regression (SVR)
# ## Definition
# - It is a type of machine learning algorithm used for regression tasks. It is an extension of the Support Vector Machine (SVM) algorithm, which is commonly used for classification tasks. SVR aims to find the best hyperplane that can separate the data points into two classes or predict a continuous value.
# - Hyperplane is similar to the line of best fit in linear regression. It is a hyperplane in higher dimensions that best separates the data points into two classes or predicts a continuous value.
# - SVR uses a kernel function to map the input data into a higher-dimensional space where it becomes easier to find a hyperplane that separates the data points. The kernel function transforms the input data into a higher-dimensional space, allowing the algorithm to find a hyperplane that can accurately separate the data points into two classes or predict a continuous value.
# - SVR is a non-parametric algorithm, which means it does not make any assumptions about the underlying data distribution. It is a powerful algorithm that can handle both linear and non-linear data.
# - SVR is a supervised learning algorithm, which means it requires labeled data to train the model. The labeled data is used to find the best hyperplane that can separate the data points into two classes or predict a continuous value.
# - SVR is a flexible algorithm that can handle both linear and non-linear data. It can be used for both regression and classification tasks.
# - SVR is a popular algorithm in machine learning and is widely used for regression tasks. It is a powerful algorithm that can handle both linear and non-linear data and can be used for both regression and classification tasks.
# - SVR is a non-parametric algorithm, which means it does not make any assumptions about the underlying data distribution. It is a flexible algorithm that can handle both linear and non-linear data and can be used for both regression and classification tasks.
# - SVR is a powerful algorithm that can handle both linear and non-linear data and can be used for both regression and classification tasks.
# - Decision boundaries or support vectors are the hyperplanes that best separate the data points into two classes or predict a continuous value.
# - The distance between the data points and the hyperplane is called the margin. The margin is the largest distance between the two support vectors
# - Marginal should be maximum we can adjust the error to get more accuracy for future prediction.
# - in SVR, the equation of hyperplane is y = wx + b

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv(r"D:\Dropbox\DS & AI\Full stack DS and AI course\24 Jun\emp_sal.csv")

# %%
X = dataset.iloc[:, 1:2].values  
y = dataset.iloc[:, 2].values

# %% [markdown]
# ## Visualizing the polynomial model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures()
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
#in y-coordinate we have to replace with lin_reg2 which we create for poly regression model
#X_poly is not defined cuz we already defined in above plot, so insted of X_poly we will define complete fit_trasnform code 
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
poly_model_pred = lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
print(poly_model_pred)
# Out:
# [189498.10606061]

# %%
from sklearn.svm import SVR
svr_model =SVR()
svr_model.fit(X, y)
svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [130001.82883924]

# %%
from sklearn.svm import SVR
svr_model =SVR(kernel="rbf", degree=4, gamma='scale')  # Using radial basis function kernel
svr_model.fit(X, y)
svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [130001.82883924]

# %%
from sklearn.svm import SVR
svr_model =SVR(kernel="rbf", degree=5, gamma='scale')  # Using radial basis function kernel
svr_model.fit(X, y)
svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [130001.82883924]

# %%
from sklearn.svm import SVR
svr_model =SVR(kernel="poly", degree=4, gamma='scale')  # Using radial basis function kernel
svr_model.fit(X, y)
svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)
# Out:
# [134160.63306167]

# %%
from sklearn.svm import SVR
svr_model =SVR(kernel="rbf", degree=5, gamma='scale',C=10.0)  # Using radial basis function kernel
svr_model.fit(X, y)
svr_model_pred = svr_model.predict([[6.5]])
print(svr_model_pred)

# You can change the kernel and degree parameters to see how they affect the model's performance.
# Out:
# [130018.28839241]

# %% [markdown]
# ## Visualising the SVR results

# %%
# Visualising the SVR results
plt.scatter(X, y, color = 'red')
plt.plot(X, svr_model.predict(X), color = 'blue')
plt.title('Truth or Bluff (SVR)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
#if you check the output that is svr model & its predicting the each of the real observation
#red points are real observation point & blue lines are predicted line & now you can say svr is fitted much better curve on the dataset
#same hear if you check the ceo actual observation point but you will find as still we can improve the graph and lets see how can we do that in svr
#in this case ceo is outlier hear becuase ceo is quite far from our observation, thats ok

#what exactly we are doing hear to check the what exactly employees have 6.5yrs experience predict salary

# %%
# Visualising the SVR results (for higher resolution and smoother curve)
X_grid = np.arange(min(X), max(X), 0.01) # choice of 0.01 instead of 0.1 step because the data is feature scaled
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, svr_model.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (SVR)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

#great curve you got isn't it , same dataset you worked polynomial regressor & svm regressor 
# you can see the difference between them
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1560\2366103722.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.01) # choice of 0.01 instead of 0.1 step because the data is feature scaled

# %% [markdown]
# ## KNN REGRESSION

# %% [markdown]
# - Let us finish regression part then we move to classification part later
# - The KNN Regression: K Nearest Neighbor Regression
# - The KNN is a regression algorithm that uses the K nearest neighbors to predict the value of a new data point.
# - The KNN Regression algorithm is a supervised learning algorithm that is used for regression tasks. It is a type of machine learning algorithm that is used to predict the value of a continuous variable. It is a non-parametric algorithm, which means that it does not make any assumptions about the underlying data distribution. It is also a lazy learning algorithm, which means that it does not learn from the training data, but rather it makes predictions on the fly.
# - The KNN Regression algorithm is based on the concept of similarity. It works by finding the K nearest neighbors of a new data point and then using their values to predict the value of the new data point. The value of K is a hyperparameter that needs to be tuned. The value of K is the number of neighbors that are considered when making a prediction. The value of K is usually chosen by cross-validation.
# - The KNN Regression algorithm is a powerful algorithm that can be used for a wide range of regression tasks. It is particularly useful when the data is not linearly separable. It is also useful when the data is noisy. It is also useful when the data is high-dimensional.
# - The KNN equation is : y = y_mean + (y_mean - y_mean_k) * (x - x_mean) / (x_mean - x_mean_k)
# - Euclidian distance = sqrt((x1 - x2)^2 + (y1 - y2)^2) is the shortest distance between two points.
# - Manhattan distance = |x1 - x2| + |y1 - y2| is the farthest distance between two points.
# - Cosin distance = 1 - (cos(x1,x2)) finds the distance between text (vector)

# %%
# Let us build the KNN model
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor()  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Very important to understand the parameters of the KNN model
# n_neighbors: The number of neighbors to use for prediction. You can change this value to see how it affects the model's performance.
# weights: The weight function used in prediction. You can change this value to see how it affects the model's performance.
# algorithm: The algorithm used to compute the nearest neighbors. You can change this value to see how it affects the model's performance.
# Use the spyder to change the parameters and see how they affect the model's performance.
# sklearn is a combination of maths, statistics, and computer science.
# metrics: The distance metric used to compute the nearest neighbors. You can change this value to see how it affects the model's performance.
# Out:
# [168000.]

# %% [markdown]
# - Definition : KNeighborsRegressor(n_neighbors=5, *, weights="uniform", algorithm="auto", leaf_size=30, p=2, metric="minkowski", metric_params=None, n_jobs=None)
# - Parameters
#    n_neighborsint, default=5
# Number of neighbors to use by default for kneighbors() queries.
#    weights{'uniform', 'distance'}, callable or None, default='uniform'
# Weight function used in prediction. Possible values:
#
# 'uniform' : uniform weights. All points in each neighborhood are weighted equally.
#
# 'distance' : weight points by the inverse of their distance. in this case, closer neighbors of a query point will have a greater influence than neighbors which are further away.
#
# [callable] : a user-defined function which accepts an array of distances, and returns an array of the same shape containing the weights.
#
# Uniform weights are used by default.
#
#    algorithm{'auto', 'ball_tree', 'kd_tree', 'brute'}, default='auto'
# Algorithm used to compute the nearest neighbors:
#
# 'ball_tree' will use BallTree
#
# 'kd_tree' will use KDTree
#
# 'brute' will use a brute-force search.
#
# 'auto' will attempt to decide the most appropriate algorithm based on the values passed to fit() method.
#
# Note: fitting on sparse input will override the setting of this parameter, using brute force.
#
#    leaf_sizeint, default=30
# Leaf size passed to BallTree or KDTree. This can affect the speed of the construction and query, as well as the memory required to store the tree. The optimal value depends on the nature of the problem.
#
# pfloat, default=2
# Power parameter for the Minkowski metric. When p = 1, this is equivalent to using manhattan_distance (l1), and euclidean_distance (l2) for p = 2. For arbitrary p, minkowski_distance (l_p) is used.
#
#    metricstr, DistanceMetric object or callable, default='minkowski'
# Metric to use for distance computation. Default is "minkowski", which results in the standard Euclidean distance when p = 2. See the documentation of scipy.spatial.distance and the metrics listed in distance_metrics for valid metric values.
#
# If metric is "precomputed", X is assumed to be a distance matrix and must be square during fit. X may be a sparse graph, in which case only "nonzero" elements may be considered neighbors.
#
# If metric is a callable function, it takes two arrays representing 1D vectors as inputs and must return one value indicating the distance between those vectors. This works for Scipy's metrics, but is less efficient than passing the metric name as a string.
#
# If metric is a DistanceMetric object, it will be passed directly to the underlying computation routines.
#
# metric_paramsdict, default=None
# Additional keyword arguments for the metric function.
#
# n_jobsint, default=None
# The number of parallel jobs to run for neighbors search. None means 1 unless in a joblib.parallel_backend context. -1 means using all processors. See Glossary for more details. Doesn't affect fit() method.
#
# Attributes
# effective_metric_str or callable
# The distance metric to use. It will be same as the metric parameter or a synonym of it, e.g. 'euclidean' if the metric parameter set to 'minkowski' and p parameter set to 2.
#
# effective_metric_params_dict
# Additional keyword arguments for the metric function. For most metrics will be same with metric_params parameter, but may also contain the p parameter value if the effective_metric_ attribute is set to 'minkowski'.
#
# n_features_in_int
# Number of features seen during fit.
#
# Added in version 0.24.
#
# feature_names_in_ndarray of shape (n_features_in_,)
# Names of features seen during fit. Defined only when X has feature names that are all strings.
#
# Added in version 1.0.
#
# n_samples_fit_int
# Number of samples in the fitted data.

# %%
# Let's do hyperparameter tuning on SVR
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=3)  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Note the change made in the n_neighbors parameter, which is set to 3.
# This is a hyperparameter that we can tune to improve the model's performance.
# as an exercise, open the algorithm, build a hyperparameter tuning table in an excel sheet and post for discussion.
# Out:
# [153333.33333333]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=8,weights='distance',algorithm='brute',leaf_size=25,p=4,metric='canberra')  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [243299.82517483]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=8,weights='distance',algorithm='ball_tree',leaf_size=20,p=8,metric='jaccard')  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [124375.]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=8,weights='distance',algorithm='ball_tree',leaf_size=20,metric='jaccard')  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [124375.]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=8,weights='distance',algorithm='ball_tree',metric='jaccard')  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [124375.]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=8,weights='distance',algorithm='ball_tree')  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [224943.18181818]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=8,weights='distance',metric='jaccard')  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [179375.]
# c:\Users\Dell\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:2361: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=8,weights='distance',algorithm='kd_tree')  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [224943.18181818]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=8,weights='distance',algorithm='kd_tree',metric='cityblock',p=2)  # You can change n_neighbors to see how it affects the model
knn_model.fit(X,y)
knn_model_pred = knn_model.predict([[6.5]])
print(knn_model_pred)
# Out:
# [224943.18181818]

# %% [markdown]
# # Mlxtend (machine learning extensions)
#
# is a Python library of useful tools for the day-to-day data science tasks.

# %%
# %pip install mlxtend
# mlxtend is
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.data import iris_data
from mlxtend.plotting import plot_decision_regions

# Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = SVC(random_state=0, probability=True)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3], weights=[2, 1, 1], voting='soft')

# Loading some example data
X, y = iris_data()
X = X[:,[0, 2]]

# Plotting Decision Regions
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         ['Logistic Regression', 'Random Forest', 'RBF kernel SVM', 'Ensemble'],
                         itertools.product([0, 1], repeat=2)):
    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X, y=y, clf=clf, legend=2)
    plt.title(lab)
plt.show()
